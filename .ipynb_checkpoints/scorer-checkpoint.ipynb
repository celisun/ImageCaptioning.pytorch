# %%
from coco-caption.pycocoevalcap
import json
captions = [[cap['image_id'], cap['caption']] for cap in json.load(open('vis0.json', 'r'))]
captions.sort()
prediction = [c[1].split(" ") for c in captions]
captions
# Out:
# [[0, 'a table with a laptop and a laptop'],
#  [1, 'a cow is standing in the grass in the woods'],
#  [2, 'a man in a black shirt is standing in a bathroom'],
#  [3, 'a street sign that has a bunch of stickers on it'],
#  [4, 'a black and white cat laying on a bed'],
#  [5, 'a plate of food with broccoli on top'],
#  [6, 'a close up of a pizza on a table'],
#  [7, 'a man holding a hot dog in his mouth'],
#  [8, 'a living room with a couch and a table'],
#  [9, 'a cat laying on top of a bed'],
#  [10, 'a giraffe standing in a field near trees'],
#  [11, 'a desk with a laptop and a laptop on it'],
#  [12, 'a man holding a hot dog in his mouth'],
#  [13, 'a group of people sitting on a bench in a garden'],
#  [14, 'a piece of cake on a plate on a table'],
#  [15, 'a stop sign that is on a road'],
#  [16, 'a person on a snow board in the snow'],
#  [17, 'a close up of a person holding a cell phone'],
#  [18, 'a cat laying on top of a bed with a blanket'],
# ...
